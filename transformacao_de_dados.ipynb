# %%
import pandas as pd
import pandera  as pa  # biblioteca para validação de extração de dados

# %%
valores_ausentes = ['**', '###!','####','****','*****','NULL']
df = pd.read_csv("ocorrencia_2010_2020.csv", sep=";", parse_dates=["ocorrencia_dia"], dayfirst=True, na_values=valores_ausentes)
df.head()
# Out:
#    codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0              40211               40211                INCIDENTE
# 1              40349               40349                INCIDENTE
# 2              40351               40351                INCIDENTE
# 3              39527               39527                 ACIDENTE
# 4              40324               40324                INCIDENTE
#
#     ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 0      RIO DE JANEIRO            RJ                  NaN     2010-01-03
# 1               BELÉM            PA                 SBBE     2010-01-03
# 2      RIO DE JANEIRO            RJ                 SBRJ     2010-01-03
# 3  LUCAS DO RIO VERDE            MT                  NaN     2010-01-04
# 4             PELOTAS            RS                 SBPK     2010-01-05
#
#   ocorrencia_hora  total_recomendacoes
# 0        12:00:00                    0
# 1        11:05:00                    0
# 2        03:00:00                    0
# 3        17:30:00                    0
# 4        19:25:00                    0

# %%
# Validação de dados das Colunas- Schema
schema = pa.DataFrameSchema(
    columns = {
        "codigo": pa.Column(pa.Int, required=False),
        "codigo_ocorrencia":pa.Column(pa.Int),
        "codigo_ocorrencia2":pa.Column(pa.Int),
        "ocorrencia_classificacao":pa.Column(pa.String),
        "ocorrencia_uf":pa.Column(pa.String, nullable=True),#pa.Check.str_length(2,2),),
        "ocorrencia_aerodromo":pa.Column(pa.String, nullable=True),
        "ocorrencia_dia":pa.Column(pa.DateTime),
        "ocorrencia_hora":pa.Column(pa.String, pa.Check.str_matches(r'^([0-1]?[0-9]|[2][0-3]):([0-5][0-9])(:[0-5][0-9])?$'), nullable=True),
         "total_recomendacoes":pa.Column(pa.Int)
    }
)

# %%
schema.validate(df)
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0                 40211               40211                INCIDENTE
# 1                 40349               40349                INCIDENTE
# 2                 40351               40351                INCIDENTE
# 3                 39527               39527                 ACIDENTE
# 4                 40324               40324                INCIDENTE
# ...                 ...                 ...                      ...
# 5747              79804               79804                INCIDENTE
# 5748              79757               79757          INCIDENTE GRAVE
# 5749              79802               79802                INCIDENTE
# 5750              79756               79756          INCIDENTE GRAVE
# 5751              79844               79844                INCIDENTE
#
#        ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 0         RIO DE JANEIRO            RJ                  NaN     2010-01-03
# 1                  BELÉM            PA                 SBBE     2010-01-03
# 2         RIO DE JANEIRO            RJ                 SBRJ     2010-01-03
# 3     LUCAS DO RIO VERDE            MT                  NaN     2010-01-04
# 4                PELOTAS            RS                 SBPK     2010-01-05
# ...                  ...           ...                  ...            ...
# 5747            CAMPINAS            SP                 SBKP     2020-12-29
# 5748   LAGOA DA CONFUSÃO            TO                  NaN     2020-12-30
# 5749      RIO DE JANEIRO            RJ                 SBGL     2020-12-30
# 5750           VICENTINA            MS                  NaN     2020-12-31
# 5751      RIO DE JANEIRO            RJ                 SBJR     2020-12-31
#
#      ocorrencia_hora  total_recomendacoes
# 0           12:00:00                    0
# 1           11:05:00                    0
# 2           03:00:00                    0
# 3           17:30:00                    0
# 4           19:25:00                    0
# ...              ...                  ...
# 5747        19:00:00                    0
# 5748        18:30:00                    0
# 5749        00:54:00                    0
# 5750        09:00:00                    0
# 5751        13:24:00                    0
#
# [5752 rows x 9 columns]

# %%
df.dtypes
# Out:
# codigo_ocorrencia                    int64
# codigo_ocorrencia2                   int64
# ocorrencia_classificacao            object
# ocorrencia_cidade                   object
# ocorrencia_uf                       object
# ocorrencia_aerodromo                object
# ocorrencia_dia              datetime64[ns]
# ocorrencia_hora                     object
# total_recomendacoes                  int64
# dtype: object

# %%
df.loc[2]
# Out:
# codigo_ocorrencia                         40351
# codigo_ocorrencia2                        40351
# ocorrencia_classificacao              INCIDENTE
# ocorrencia_cidade                RIO DE JANEIRO
# ocorrencia_uf                                RJ
# ocorrencia_aerodromo                       SBRJ
# ocorrencia_dia              2010-01-03 00:00:00
# ocorrencia_hora                        03:00:00
# total_recomendacoes                           0
# Name: 2, dtype: object

# %%
# obtendo informação pelo indice
df.iloc[-1]
# Out:
# codigo_ocorrencia                         79844
# codigo_ocorrencia2                        79844
# ocorrencia_classificacao              INCIDENTE
# ocorrencia_cidade                RIO DE JANEIRO
# ocorrencia_uf                                RJ
# ocorrencia_aerodromo                       SBJR
# ocorrencia_dia              2020-12-31 00:00:00
# ocorrencia_hora                        13:24:00
# total_recomendacoes                           0
# Name: 5751, dtype: object

# %%
df.iloc[10:15]
# Out:
#     codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 10              39789               39789                INCIDENTE
# 11              40069               40069                 ACIDENTE
# 12              40414               40414                INCIDENTE
# 13              39507               39507                 ACIDENTE
# 14              40107               40107                 ACIDENTE
#
#      ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 10    SÃO PEDRO DO SUL            RS                  NaN     2010-01-10
# 11           SÃO PAULO            SP                 SBMT     2010-01-10
# 12            BRASÍLIA            DF                 SBBR     2010-01-10
# 13  PRIMAVERA DO LESTE            MT                  NaN     2010-01-11
# 14              GURUPÁ            PA                 SNGU     2010-01-12
#
#    ocorrencia_hora  total_recomendacoes
# 10        21:30:00                    0
# 11        14:50:00                    8
# 12        03:00:00                    0
# 13        17:00:00                    2
# 14        14:30:00                    0

# %%
# buscando por label
df.loc[10:15]
# Out:
#     codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 10              39789               39789                INCIDENTE
# 11              40069               40069                 ACIDENTE
# 12              40414               40414                INCIDENTE
# 13              39507               39507                 ACIDENTE
# 14              40107               40107                 ACIDENTE
# 15              39315               39315                 ACIDENTE
#
#      ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 10    SÃO PEDRO DO SUL            RS                  NaN     2010-01-10
# 11           SÃO PAULO            SP                 SBMT     2010-01-10
# 12            BRASÍLIA            DF                 SBBR     2010-01-10
# 13  PRIMAVERA DO LESTE            MT                  NaN     2010-01-11
# 14              GURUPÁ            PA                 SNGU     2010-01-12
# 15            CANUTAMA            AM                  NaN     2010-01-15
#
#    ocorrencia_hora  total_recomendacoes
# 10        21:30:00                    0
# 11        14:50:00                    8
# 12        03:00:00                    0
# 13        17:00:00                    2
# 14        14:30:00                    0
# 15        21:22:00                    0

# %%
df.loc[:,'ocorrencia_uf']
# Out:
# 0       RJ
# 1       PA
# 2       RJ
# 3       MT
# 4       RS
#         ..
# 5747    SP
# 5748    TO
# 5749    RJ
# 5750    MS
# 5751    RJ
# Name: ocorrencia_uf, Length: 5752, dtype: object

# %%
# valores não informados
df.isna().sum()
# Out:
# codigo_ocorrencia              0
# codigo_ocorrencia2             0
# ocorrencia_classificacao       0
# ocorrencia_cidade              0
# ocorrencia_uf                  0
# ocorrencia_aerodromo        2349
# ocorrencia_dia                 0
# ocorrencia_hora                1
# total_recomendacoes            0
# dtype: int64

# %%
# coluna ocorrencia_hora com valores NaN
filtroOcorrencia_hora = df.ocorrencia_hora.isnull()
df.loc[filtroOcorrencia_hora]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 4100              78823               78823                INCIDENTE
#
#      ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 4100           CORUMBÁ            MS                  NaN     2017-07-09
#
#      ocorrencia_hora  total_recomendacoes
# 4100             NaN                    0

# %%
# coluna ocorrencia_aerodromo com valores NaN
filtroOcorrencia_aerodromo = df.ocorrencia_aerodromo.isnull()
df.loc[filtroOcorrencia_aerodromo]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0                 40211               40211                INCIDENTE
# 3                 39527               39527                 ACIDENTE
# 5                 39807               39807                INCIDENTE
# 7                 39707               39707          INCIDENTE GRAVE
# 9                 39711               39711          INCIDENTE GRAVE
# ...                 ...                 ...                      ...
# 5741              79754               79754          INCIDENTE GRAVE
# 5744              79753               79753          INCIDENTE GRAVE
# 5745              79755               79755                 ACIDENTE
# 5748              79757               79757          INCIDENTE GRAVE
# 5750              79756               79756          INCIDENTE GRAVE
#
#        ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 0         RIO DE JANEIRO            RJ                  NaN     2010-01-03
# 3     LUCAS DO RIO VERDE            MT                  NaN     2010-01-04
# 5               SALVADOR            BA                  NaN     2010-01-06
# 7               CANUTAMA            AM                  NaN     2010-01-09
# 9          PARÁ DE MINAS            MG                  NaN     2010-01-10
# ...                  ...           ...                  ...            ...
# 5741        NOVA MARINGÁ            MT                  NaN     2020-12-28
# 5744            GOIATUBA            GO                  NaN     2020-12-29
# 5745           MATO RICO            PR                  NaN     2020-12-29
# 5748   LAGOA DA CONFUSÃO            TO                  NaN     2020-12-30
# 5750           VICENTINA            MS                  NaN     2020-12-31
#
#      ocorrencia_hora  total_recomendacoes
# 0           12:00:00                    0
# 3           17:30:00                    0
# 5           17:53:00                    0
# 7           12:30:00                    3
# 9           20:00:00                    0
# ...              ...                  ...
# 5741        13:00:00                    0
# 5744        12:00:00                    0
# 5745        10:30:00                    0
# 5748        18:30:00                    0
# 5750        09:00:00                    0
#
# [2349 rows x 9 columns]

# %%
df.count()
# Out:
# codigo_ocorrencia           5752
# codigo_ocorrencia2          5752
# ocorrencia_classificacao    5752
# ocorrencia_cidade           5752
# ocorrencia_uf               5752
# ocorrencia_aerodromo        3403
# ocorrencia_dia              5752
# ocorrencia_hora             5751
# total_recomendacoes         5752
# dtype: int64

# %%
# ocorrências com mais de 10 recomendações
filtro = df.total_recomendacoes > 10
df.loc[filtro]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 63                39992               39992                 ACIDENTE
# 326               42250               42250                 ACIDENTE
# 530               43471               43471                 ACIDENTE
# 727               44377               44377                 ACIDENTE
# 872               44796               44796                 ACIDENTE
# 884               44888               44888          INCIDENTE GRAVE
# 1062              45554               45554          INCIDENTE GRAVE
# 1972              47938               47938                INCIDENTE
# 2795              52265               52265                 ACIDENTE
# 3930              66432               66432          INCIDENTE GRAVE
#
#          ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 63               SÃO PAULO            SP                 SBMT     2010-02-17
# 326         RIO DE JANEIRO            RJ                 SBRJ     2010-08-12
# 530              SÃO PAULO            SP                  NaN     2010-12-14
# 727               ITÁPOLIS            SP                 SDIO     2011-04-09
# 872                 RECIFE            PE                 SBRF     2011-07-13
# 884   SÃO JOSÉ DOS PINHAIS            PR                 SBCT     2011-07-15
# 1062            UBERLÂNDIA            MG                 SBUL     2011-11-15
# 1972              BRASÍLIA            DF                 SBBR     2013-04-13
# 2795                SANTOS            SP                  NaN     2014-08-13
# 3930               VITÓRIA            ES                  NaN     2017-02-21
#
#      ocorrencia_hora  total_recomendacoes
# 63          20:07:00                   11
# 326         12:26:00                   19
# 530         20:15:00                   11
# 727         14:50:00                   11
# 872         09:54:00                   23
# 884         17:05:00                   11
# 1062        02:15:00                   20
# 1972        18:00:00                   11
# 2795        13:03:00                   13
# 3930        11:47:00                   12

# %%
# ocorrências com mais de 10 recomendações
filtro = df.total_recomendacoes > 10
df.loc[filtro, ['ocorrencia_cidade', 'total_recomendacoes']]
# Out:
#          ocorrencia_cidade  total_recomendacoes
# 63               SÃO PAULO                   11
# 326         RIO DE JANEIRO                   19
# 530              SÃO PAULO                   11
# 727               ITÁPOLIS                   11
# 872                 RECIFE                   23
# 884   SÃO JOSÉ DOS PINHAIS                   11
# 1062            UBERLÂNDIA                   20
# 1972              BRASÍLIA                   11
# 2795                SANTOS                   13
# 3930               VITÓRIA                   12

# %%
# ocorrências com classificação == INCIDENTE GRAVE
filtro = df.ocorrencia_classificacao == 'INCIDENTE GRAVE'
df.loc[filtro, ['ocorrencia_cidade', 'total_recomendacoes']]
# Out:
#       ocorrencia_cidade  total_recomendacoes
# 7              CANUTAMA                    3
# 8              CASCAVEL                    2
# 9         PARÁ DE MINAS                    0
# 29             CURITIBA                    2
# 35               PALMAS                    0
# ...                 ...                  ...
# 5741       NOVA MARINGÁ                    0
# 5744           GOIATUBA                    0
# 5746      MANOEL URBANO                    0
# 5748  LAGOA DA CONFUSÃO                    0
# 5750          VICENTINA                    0
#
# [737 rows x 2 columns]

# %%
# Todas ocorrências com classificação == INCIDENTE GRAVE
filtro = df.ocorrencia_classificacao == 'INCIDENTE GRAVE'
df.loc[filtro]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 7                 39707               39707          INCIDENTE GRAVE
# 8                 39156               39156          INCIDENTE GRAVE
# 9                 39711               39711          INCIDENTE GRAVE
# 29                39709               39709          INCIDENTE GRAVE
# 35                39487               39487          INCIDENTE GRAVE
# ...                 ...                 ...                      ...
# 5741              79754               79754          INCIDENTE GRAVE
# 5744              79753               79753          INCIDENTE GRAVE
# 5746              79769               79769          INCIDENTE GRAVE
# 5748              79757               79757          INCIDENTE GRAVE
# 5750              79756               79756          INCIDENTE GRAVE
#
#       ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 7              CANUTAMA            AM                  NaN     2010-01-09
# 8              CASCAVEL            PR                 SBCA     2010-01-10
# 9         PARÁ DE MINAS            MG                  NaN     2010-01-10
# 29             CURITIBA            PR                 SBBI     2010-01-23
# 35               PALMAS            TO                 SBPJ     2010-01-26
# ...                 ...           ...                  ...            ...
# 5741       NOVA MARINGÁ            MT                  NaN     2020-12-28
# 5744           GOIATUBA            GO                  NaN     2020-12-29
# 5746      MANOEL URBANO            AC                 SIMB     2020-12-29
# 5748  LAGOA DA CONFUSÃO            TO                  NaN     2020-12-30
# 5750          VICENTINA            MS                  NaN     2020-12-31
#
#      ocorrencia_hora  total_recomendacoes
# 7           12:30:00                    3
# 8           23:15:00                    2
# 9           20:00:00                    0
# 29          16:36:00                    2
# 35          16:50:00                    0
# ...              ...                  ...
# 5741        13:00:00                    0
# 5744        12:00:00                    0
# 5746        18:30:00                    0
# 5748        18:30:00                    0
# 5750        09:00:00                    0
#
# [737 rows x 9 columns]

# %%
# Todas ocorrências com classificação == INCIDENTE GRAVE e no estado ==  SP
filtro1 = df.ocorrencia_classificacao == 'INCIDENTE GRAVE'
filtro2 = df.ocorrencia_uf == 'SP'
df.loc[filtro1 & filtro2]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 136               40270               40270          INCIDENTE GRAVE
# 171               40620               40620          INCIDENTE GRAVE
# 219               41411               41411          INCIDENTE GRAVE
# 297               42289               42289          INCIDENTE GRAVE
# 314               42323               42323          INCIDENTE GRAVE
# ...                 ...                 ...                      ...
# 5591              79540               79540          INCIDENTE GRAVE
# 5610              79566               79566          INCIDENTE GRAVE
# 5704              79739               79739          INCIDENTE GRAVE
# 5705              79705               79705          INCIDENTE GRAVE
# 5715              79718               79718          INCIDENTE GRAVE
#
#           ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 136            PIRASSUNUNGA            SP                 SDPY     2010-04-15
# 171               GUARULHOS            SP                 SBGR     2010-05-06
# 219               SÃO PAULO            SP                 SBMT     2010-06-08
# 297               SÃO PAULO            SP                 SBMT     2010-07-29
# 314   SÃO JOSÉ DO RIO PRETO            SP                 SBSR     2010-08-05
# ...                     ...           ...                  ...            ...
# 5591              SÃO PAULO            SP                  NaN     2020-09-12
# 5610          REGENTE FEIJÓ            SP                 SDYJ     2020-09-27
# 5704              SÃO PAULO            SP                 SBSP     2020-12-03
# 5705               SOROCABA            SP                 SDCO     2020-12-04
# 5715              SÃO PAULO            SP                 SBMT     2020-12-11
#
#      ocorrencia_hora  total_recomendacoes
# 136         20:15:00                    0
# 171         15:50:00                    0
# 219         19:30:00                    2
# 297         20:06:00                    0
# 314         12:01:00                    0
# ...              ...                  ...
# 5591        13:10:00                    0
# 5610        19:33:00                    0
# 5704        14:42:00                    0
# 5705        15:30:00                    0
# 5715        13:50:00                    0
#
# [137 rows x 9 columns]

# %%
# Todas ocorrências com classificação == INCIDENTE GRAVE ou  estado de SP
filtro1 = df.ocorrencia_classificacao == 'INCIDENTE GRAVE'
filtro2 = df.ocorrencia_uf == 'SP'
df.loc[filtro1 | filtro2]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 7                 39707               39707          INCIDENTE GRAVE
# 8                 39156               39156          INCIDENTE GRAVE
# 9                 39711               39711          INCIDENTE GRAVE
# 11                40069               40069                 ACIDENTE
# 16                39809               39809                INCIDENTE
# ...                 ...                 ...                      ...
# 5744              79753               79753          INCIDENTE GRAVE
# 5746              79769               79769          INCIDENTE GRAVE
# 5747              79804               79804                INCIDENTE
# 5748              79757               79757          INCIDENTE GRAVE
# 5750              79756               79756          INCIDENTE GRAVE
#
#       ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 7              CANUTAMA            AM                  NaN     2010-01-09
# 8              CASCAVEL            PR                 SBCA     2010-01-10
# 9         PARÁ DE MINAS            MG                  NaN     2010-01-10
# 11            SÃO PAULO            SP                 SBMT     2010-01-10
# 16            SÃO PAULO            SP                  NaN     2010-01-15
# ...                 ...           ...                  ...            ...
# 5744           GOIATUBA            GO                  NaN     2020-12-29
# 5746      MANOEL URBANO            AC                 SIMB     2020-12-29
# 5747           CAMPINAS            SP                 SBKP     2020-12-29
# 5748  LAGOA DA CONFUSÃO            TO                  NaN     2020-12-30
# 5750          VICENTINA            MS                  NaN     2020-12-31
#
#      ocorrencia_hora  total_recomendacoes
# 7           12:30:00                    3
# 8           23:15:00                    2
# 9           20:00:00                    0
# 11          14:50:00                    8
# 16          15:00:00                    0
# ...              ...                  ...
# 5744        12:00:00                    0
# 5746        18:30:00                    0
# 5747        19:00:00                    0
# 5748        18:30:00                    0
# 5750        09:00:00                    0
#
# [1973 rows x 9 columns]

# %%
#  ocorrências com (classificação == INCIDENTE GRAVE  ou   classificação == INCIDENTE) e o  estado de SP
filtro1 = (df.ocorrencia_classificacao == 'INCIDENTE GRAVE') | (df.ocorrencia_classificacao == 'INCIDENTE')
filtro2 = df.ocorrencia_uf == 'SP'
df.loc[filtro1 &  filtro2]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 16                39809               39809                INCIDENTE
# 18                39828               39828                INCIDENTE
# 26                39847               39847                INCIDENTE
# 27                39768               39768                INCIDENTE
# 33                39848               39848                INCIDENTE
# ...                 ...                 ...                      ...
# 5704              79739               79739          INCIDENTE GRAVE
# 5705              79705               79705          INCIDENTE GRAVE
# 5715              79718               79718          INCIDENTE GRAVE
# 5742              79800               79800                INCIDENTE
# 5747              79804               79804                INCIDENTE
#
#      ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 16           SÃO PAULO            SP                  NaN     2010-01-15
# 18              SANTOS            SP                  NaN     2010-01-15
# 26            SOROCABA            SP                  NaN     2010-01-20
# 27            CAMPINAS            SP                  NaN     2010-01-21
# 33           GUARULHOS            SP                 SBGR     2010-01-25
# ...                ...           ...                  ...            ...
# 5704         SÃO PAULO            SP                 SBSP     2020-12-03
# 5705          SOROCABA            SP                 SDCO     2020-12-04
# 5715         SÃO PAULO            SP                 SBMT     2020-12-11
# 5742         SÃO PAULO            SP                 SBMT     2020-12-28
# 5747          CAMPINAS            SP                 SBKP     2020-12-29
#
#      ocorrencia_hora  total_recomendacoes
# 16          15:00:00                    0
# 18          17:45:00                    0
# 26          13:10:00                    0
# 27          20:45:00                    0
# 33          17:05:00                    0
# ...              ...                  ...
# 5704        14:42:00                    0
# 5705        15:30:00                    0
# 5715        13:50:00                    0
# 5742        10:15:00                    0
# 5747        19:00:00                    0
#
# [985 rows x 9 columns]

# %%
# ocorrências por Ano
filtro_ano = df.ocorrencia_dia.dt.year == 2020
df.loc[filtro_ano]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 5242              79043               79043                 ACIDENTE
# 5243              79044               79044          INCIDENTE GRAVE
# 5244              79049               79049                 ACIDENTE
# 5245              79132               79132                INCIDENTE
# 5246              79182               79182                INCIDENTE
# ...                 ...                 ...                      ...
# 5747              79804               79804                INCIDENTE
# 5748              79757               79757          INCIDENTE GRAVE
# 5749              79802               79802                INCIDENTE
# 5750              79756               79756          INCIDENTE GRAVE
# 5751              79844               79844                INCIDENTE
#
#       ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 5242        CAMANDUCAIA            MG                 SNEJ     2020-01-01
# 5243           SALVADOR            BA                 SBSV     2020-01-03
# 5244               LEME            SP                  NaN     2020-01-03
# 5245         SÃO MATEUS            ES                  NaN     2020-01-03
# 5246            GOIÂNIA            GO                 SBGO     2020-01-03
# ...                 ...           ...                  ...            ...
# 5747           CAMPINAS            SP                 SBKP     2020-12-29
# 5748  LAGOA DA CONFUSÃO            TO                  NaN     2020-12-30
# 5749     RIO DE JANEIRO            RJ                 SBGL     2020-12-30
# 5750          VICENTINA            MS                  NaN     2020-12-31
# 5751     RIO DE JANEIRO            RJ                 SBJR     2020-12-31
#
#      ocorrencia_hora  total_recomendacoes
# 5242        21:00:00                    0
# 5243        16:35:00                    0
# 5244        21:15:00                    0
# 5245        14:10:00                    0
# 5246        11:10:00                    0
# ...              ...                  ...
# 5747        19:00:00                    0
# 5748        18:30:00                    0
# 5749        00:54:00                    0
# 5750        09:00:00                    0
# 5751        13:24:00                    0
#
# [510 rows x 9 columns]

# %%
# ocorrências por Ano e mês
filtro_ano = df.ocorrencia_dia.dt.year == 2020
filtro_mes = df.ocorrencia_dia.dt.month == 12
df.loc[filtro_ano & filtro_mes]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 5701              79750               79750                INCIDENTE
# 5702              79701               79701                 ACIDENTE
# 5703              79702               79702                INCIDENTE
# 5704              79739               79739          INCIDENTE GRAVE
# 5705              79705               79705          INCIDENTE GRAVE
# 5706              79707               79707                INCIDENTE
# 5707              79712               79712          INCIDENTE GRAVE
# 5708              79713               79713                 ACIDENTE
# 5709              79711               79711                INCIDENTE
# 5710              79714               79714                INCIDENTE
# 5711              79717               79717                 ACIDENTE
# 5712              79725               79725                INCIDENTE
# 5713              79716               79716          INCIDENTE GRAVE
# 5714              79720               79720                 ACIDENTE
# 5715              79718               79718          INCIDENTE GRAVE
# 5716              79724               79724                 ACIDENTE
# 5717              79719               79719                 ACIDENTE
# 5718              79722               79722          INCIDENTE GRAVE
# 5719              79723               79723                 ACIDENTE
# 5720              79726               79726          INCIDENTE GRAVE
# 5721              79729               79729                 ACIDENTE
# 5722              79738               79738                INCIDENTE
# 5723              79737               79737                INCIDENTE
# 5724              79740               79740                INCIDENTE
# 5725              79741               79741                INCIDENTE
# 5726              79742               79742                 ACIDENTE
# 5727              79743               79743                 ACIDENTE
# 5728              79744               79744                INCIDENTE
# 5729              79752               79752                INCIDENTE
# 5730              79785               79785                INCIDENTE
# 5731              79746               79746                INCIDENTE
# 5732              79745               79745                INCIDENTE
# 5733              79759               79759                INCIDENTE
# 5734              79766               79766          INCIDENTE GRAVE
# 5735              79799               79799                INCIDENTE
# 5736              79776               79776                 ACIDENTE
# 5737              79748               79748                 ACIDENTE
# 5738              79787               79787                INCIDENTE
# 5739              79749               79749                 ACIDENTE
# 5740              79751               79751                 ACIDENTE
# 5741              79754               79754          INCIDENTE GRAVE
# 5742              79800               79800                INCIDENTE
# 5743              79824               79824                 ACIDENTE
# 5744              79753               79753          INCIDENTE GRAVE
# 5745              79755               79755                 ACIDENTE
# 5746              79769               79769          INCIDENTE GRAVE
# 5747              79804               79804                INCIDENTE
# 5748              79757               79757          INCIDENTE GRAVE
# 5749              79802               79802                INCIDENTE
# 5750              79756               79756          INCIDENTE GRAVE
# 5751              79844               79844                INCIDENTE
#
#               ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo  \
# 5701                    GOIÂNIA            GO                 SWNV
# 5702              QUATRO BARRAS            PR                  NaN
# 5703             RIO DE JANEIRO            RJ                 SBGL
# 5704                  SÃO PAULO            SP                 SBSP
# 5705                   SOROCABA            SP                 SDCO
# 5706             RIO DE JANEIRO            RJ                 SBRJ
# 5707                  BOM JESUS            PI                  NaN
# 5708    SANTA VITÓRIA DO PALMAR            RS                  NaN
# 5709                PORTO VELHO            RO                 SBPV
# 5710             RIO DE JANEIRO            RJ                 9PAA
# 5711           NÃO IDENTIFICADA            MT                  NaN
# 5712                   LONDRINA            PR                 SBLO
# 5713           NÃO IDENTIFICADA            MS                  NaN
# 5714     SANT'ANA DO LIVRAMENTO            RS                  NaN
# 5715                  SÃO PAULO            SP                 SBMT
# 5716             ANGRA DOS REIS            RJ                  NaN
# 5717              RIO BRILHANTE            MS                  NaN
# 5718                   PERDIZES            MG                  NaN
# 5719       SÃO JOSÉ DOS PINHAIS            PR                 SSUL
# 5720             BELO HORIZONTE            MG                 SBPR
# 5721                  TAILÂNDIA            PA                  NaN
# 5722                  ITUMBIARA            GO                  NaN
# 5723             BELO HORIZONTE            MG                 SBBH
# 5724                  RIO LARGO            AL                 SBMO
# 5725             BELO HORIZONTE            MG                 SBBH
# 5726      SANTA HELENA DE GOIÁS            GO                  NaN
# 5727                   GOIATUBA            GO                  NaN
# 5728             BELO HORIZONTE            MG                 SBCF
# 5729                   SALVADOR            BA                  NaN
# 5730                     MANAUS            AM                 SBEG
# 5731                     MANAUS            AM                 SWFN
# 5732                     MARABÁ            PA                 SBMA
# 5733               PORTO ALEGRE            RS                 SBPA
# 5734               JUIZ DE FORA            MG                 SBJF
# 5735              MUITOS CAPÕES            RS                  NaN
# 5736                 UBERLÂNDIA            MG                 SBUL
# 5737      SANTANA DO LIVRAMENTO            RS                  NaN
# 5738                  FORTALEZA            CE                 SBFZ
# 5739                   MARITUBA            PA                  NaN
# 5740  PRESIDENTE CASTELO BRANCO            PR                 SSXO
# 5741               NOVA MARINGÁ            MT                  NaN
# 5742                  SÃO PAULO            SP                 SBMT
# 5743              RIO PARANAÍBA            MG                 SNRP
# 5744                   GOIATUBA            GO                  NaN
# 5745                  MATO RICO            PR                  NaN
# 5746              MANOEL URBANO            AC                 SIMB
# 5747                   CAMPINAS            SP                 SBKP
# 5748          LAGOA DA CONFUSÃO            TO                  NaN
# 5749             RIO DE JANEIRO            RJ                 SBGL
# 5750                  VICENTINA            MS                  NaN
# 5751             RIO DE JANEIRO            RJ                 SBJR
#
#      ocorrencia_dia ocorrencia_hora  total_recomendacoes
# 5701     2020-12-01        11:30:00                    0
# 5702     2020-12-02        16:35:00                    0
# 5703     2020-12-02        16:30:00                    0
# 5704     2020-12-03        14:42:00                    0
# 5705     2020-12-04        15:30:00                    0
# 5706     2020-12-05        12:25:00                    0
# 5707     2020-12-06        11:00:00                    0
# 5708     2020-12-06        13:30:00                    0
# 5709     2020-12-08        04:23:00                    0
# 5710     2020-12-08        14:50:00                    0
# 5711     2020-12-08        17:00:00                    0
# 5712     2020-12-08        18:55:00                    0
# 5713     2020-12-09        19:50:00                    0
# 5714     2020-12-09        21:30:00                    0
# 5715     2020-12-11        13:50:00                    0
# 5716     2020-12-11        21:15:00                    0
# 5717     2020-12-12        18:00:00                    0
# 5718     2020-12-12        17:22:00                    0
# 5719     2020-12-13        16:15:00                    0
# 5720     2020-12-13        13:41:00                    0
# 5721     2020-12-15        20:00:00                    0
# 5722     2020-12-16        20:30:00                    0
# 5723     2020-12-17        17:13:00                    0
# 5724     2020-12-17        14:26:00                    0
# 5725     2020-12-18        22:57:00                    0
# 5726     2020-12-18        14:00:00                    0
# 5727     2020-12-18        13:00:00                    0
# 5728     2020-12-18        02:34:00                    0
# 5729     2020-12-19        15:30:00                    0
# 5730     2020-12-19        12:37:00                    0
# 5731     2020-12-20        20:40:00                    0
# 5732     2020-12-21        08:47:00                    0
# 5733     2020-12-21        23:14:00                    0
# 5734     2020-12-21        16:20:00                    0
# 5735     2020-12-21        13:30:00                    0
# 5736     2020-12-22        21:21:00                    0
# 5737     2020-12-23        13:30:00                    0
# 5738     2020-12-23        18:30:00                    0
# 5739     2020-12-26        12:05:00                    0
# 5740     2020-12-27        12:30:00                    0
# 5741     2020-12-28        13:00:00                    0
# 5742     2020-12-28        10:15:00                    0
# 5743     2020-12-28        17:00:00                    0
# 5744     2020-12-29        12:00:00                    0
# 5745     2020-12-29        10:30:00                    0
# 5746     2020-12-29        18:30:00                    0
# 5747     2020-12-29        19:00:00                    0
# 5748     2020-12-30        18:30:00                    0
# 5749     2020-12-30        00:54:00                    0
# 5750     2020-12-31        09:00:00                    0
# 5751     2020-12-31        13:24:00                    0

# %%
# ocorrências por Ano, mês e dia
filtro_ano = df.ocorrencia_dia.dt.year == 2020
filtro_mes = df.ocorrencia_dia.dt.month == 12
filtro_dia = df.ocorrencia_dia.dt.day == 21
df.loc[filtro_ano & filtro_mes & filtro_dia]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 5732              79745               79745                INCIDENTE
# 5733              79759               79759                INCIDENTE
# 5734              79766               79766          INCIDENTE GRAVE
# 5735              79799               79799                INCIDENTE
#
#      ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 5732            MARABÁ            PA                 SBMA     2020-12-21
# 5733      PORTO ALEGRE            RS                 SBPA     2020-12-21
# 5734      JUIZ DE FORA            MG                 SBJF     2020-12-21
# 5735     MUITOS CAPÕES            RS                  NaN     2020-12-21
#
#      ocorrencia_hora  total_recomendacoes
# 5732        08:47:00                    0
# 5733        23:14:00                    0
# 5734        16:20:00                    0
# 5735        13:30:00                    0

# %%
# ocorrências por Ano, mês e intervalos de  dia
filtro_ano = df.ocorrencia_dia.dt.year == 2020
filtro_mes = df.ocorrencia_dia.dt.month == 12
filtro_dia_inicio = df.ocorrencia_dia.dt.day > 9 
filtro_dia_fim = df.ocorrencia_dia.dt.day < 20 
df.loc[filtro_ano & filtro_mes & filtro_dia_inicio & filtro_dia_fim]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 5715              79718               79718          INCIDENTE GRAVE
# 5716              79724               79724                 ACIDENTE
# 5717              79719               79719                 ACIDENTE
# 5718              79722               79722          INCIDENTE GRAVE
# 5719              79723               79723                 ACIDENTE
# 5720              79726               79726          INCIDENTE GRAVE
# 5721              79729               79729                 ACIDENTE
# 5722              79738               79738                INCIDENTE
# 5723              79737               79737                INCIDENTE
# 5724              79740               79740                INCIDENTE
# 5725              79741               79741                INCIDENTE
# 5726              79742               79742                 ACIDENTE
# 5727              79743               79743                 ACIDENTE
# 5728              79744               79744                INCIDENTE
# 5729              79752               79752                INCIDENTE
# 5730              79785               79785                INCIDENTE
#
#           ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 5715              SÃO PAULO            SP                 SBMT     2020-12-11
# 5716         ANGRA DOS REIS            RJ                  NaN     2020-12-11
# 5717          RIO BRILHANTE            MS                  NaN     2020-12-12
# 5718               PERDIZES            MG                  NaN     2020-12-12
# 5719   SÃO JOSÉ DOS PINHAIS            PR                 SSUL     2020-12-13
# 5720         BELO HORIZONTE            MG                 SBPR     2020-12-13
# 5721              TAILÂNDIA            PA                  NaN     2020-12-15
# 5722              ITUMBIARA            GO                  NaN     2020-12-16
# 5723         BELO HORIZONTE            MG                 SBBH     2020-12-17
# 5724              RIO LARGO            AL                 SBMO     2020-12-17
# 5725         BELO HORIZONTE            MG                 SBBH     2020-12-18
# 5726  SANTA HELENA DE GOIÁS            GO                  NaN     2020-12-18
# 5727               GOIATUBA            GO                  NaN     2020-12-18
# 5728         BELO HORIZONTE            MG                 SBCF     2020-12-18
# 5729               SALVADOR            BA                  NaN     2020-12-19
# 5730                 MANAUS            AM                 SBEG     2020-12-19
#
#      ocorrencia_hora  total_recomendacoes
# 5715        13:50:00                    0
# 5716        21:15:00                    0
# 5717        18:00:00                    0
# 5718        17:22:00                    0
# 5719        16:15:00                    0
# 5720        13:41:00                    0
# 5721        20:00:00                    0
# 5722        20:30:00                    0
# 5723        17:13:00                    0
# 5724        14:26:00                    0
# 5725        22:57:00                    0
# 5726        14:00:00                    0
# 5727        13:00:00                    0
# 5728        02:34:00                    0
# 5729        15:30:00                    0
# 5730        12:37:00                    0

# %%
# coluna ocorrencia_dia_hora
df['ocorrencia_dia_hora'] = pd.to_datetime(df.ocorrencia_dia.astype(str) + ' ' + df.ocorrencia_hora)

# %%
df.head()
# Out:
#    codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0              40211               40211                INCIDENTE
# 1              40349               40349                INCIDENTE
# 2              40351               40351                INCIDENTE
# 3              39527               39527                 ACIDENTE
# 4              40324               40324                INCIDENTE
#
#     ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 0      RIO DE JANEIRO            RJ                  NaN     2010-01-03
# 1               BELÉM            PA                 SBBE     2010-01-03
# 2      RIO DE JANEIRO            RJ                 SBRJ     2010-01-03
# 3  LUCAS DO RIO VERDE            MT                  NaN     2010-01-04
# 4             PELOTAS            RS                 SBPK     2010-01-05
#
#   ocorrencia_hora  total_recomendacoes ocorrencia_dia_hora
# 0        12:00:00                    0 2010-01-03 12:00:00
# 1        11:05:00                    0 2010-01-03 11:05:00
# 2        03:00:00                    0 2010-01-03 03:00:00
# 3        17:30:00                    0 2010-01-04 17:30:00
# 4        19:25:00                    0 2010-01-05 19:25:00

# %%
# ocorrência data e hora
filtro_ano = df.ocorrencia_dia_hora.dt.year == 2020
filtro_mes = df.ocorrencia_dia_hora.dt.month == 12
filtro_dia_inicio = df.ocorrencia_dia_hora.dt.day > 9 
filtro_dia_fim = df.ocorrencia_dia_hora.dt.day < 20 
df.loc[filtro_ano & filtro_mes & filtro_dia_inicio & filtro_dia_fim]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 5715              79718               79718          INCIDENTE GRAVE
# 5716              79724               79724                 ACIDENTE
# 5717              79719               79719                 ACIDENTE
# 5718              79722               79722          INCIDENTE GRAVE
# 5719              79723               79723                 ACIDENTE
# 5720              79726               79726          INCIDENTE GRAVE
# 5721              79729               79729                 ACIDENTE
# 5722              79738               79738                INCIDENTE
# 5723              79737               79737                INCIDENTE
# 5724              79740               79740                INCIDENTE
# 5725              79741               79741                INCIDENTE
# 5726              79742               79742                 ACIDENTE
# 5727              79743               79743                 ACIDENTE
# 5728              79744               79744                INCIDENTE
# 5729              79752               79752                INCIDENTE
# 5730              79785               79785                INCIDENTE
#
#           ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 5715              SÃO PAULO            SP                 SBMT     2020-12-11
# 5716         ANGRA DOS REIS            RJ                  NaN     2020-12-11
# 5717          RIO BRILHANTE            MS                  NaN     2020-12-12
# 5718               PERDIZES            MG                  NaN     2020-12-12
# 5719   SÃO JOSÉ DOS PINHAIS            PR                 SSUL     2020-12-13
# 5720         BELO HORIZONTE            MG                 SBPR     2020-12-13
# 5721              TAILÂNDIA            PA                  NaN     2020-12-15
# 5722              ITUMBIARA            GO                  NaN     2020-12-16
# 5723         BELO HORIZONTE            MG                 SBBH     2020-12-17
# 5724              RIO LARGO            AL                 SBMO     2020-12-17
# 5725         BELO HORIZONTE            MG                 SBBH     2020-12-18
# 5726  SANTA HELENA DE GOIÁS            GO                  NaN     2020-12-18
# 5727               GOIATUBA            GO                  NaN     2020-12-18
# 5728         BELO HORIZONTE            MG                 SBCF     2020-12-18
# 5729               SALVADOR            BA                  NaN     2020-12-19
# 5730                 MANAUS            AM                 SBEG     2020-12-19
#
#      ocorrencia_hora  total_recomendacoes ocorrencia_dia_hora
# 5715        13:50:00                    0 2020-12-11 13:50:00
# 5716        21:15:00                    0 2020-12-11 21:15:00
# 5717        18:00:00                    0 2020-12-12 18:00:00
# 5718        17:22:00                    0 2020-12-12 17:22:00
# 5719        16:15:00                    0 2020-12-13 16:15:00
# 5720        13:41:00                    0 2020-12-13 13:41:00
# 5721        20:00:00                    0 2020-12-15 20:00:00
# 5722        20:30:00                    0 2020-12-16 20:30:00
# 5723        17:13:00                    0 2020-12-17 17:13:00
# 5724        14:26:00                    0 2020-12-17 14:26:00
# 5725        22:57:00                    0 2020-12-18 22:57:00
# 5726        14:00:00                    0 2020-12-18 14:00:00
# 5727        13:00:00                    0 2020-12-18 13:00:00
# 5728        02:34:00                    0 2020-12-18 02:34:00
# 5729        15:30:00                    0 2020-12-19 15:30:00
# 5730        12:37:00                    0 2020-12-19 12:37:00

# %%
# filtro data de hora
filtro1 = df.ocorrencia_dia_hora >='2020-12-13 13:40:00'
filtro2 = df.ocorrencia_dia_hora <='2020-12-19 14:00:00'
df.loc[filtro1 & filtro2]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 5719              79723               79723                 ACIDENTE
# 5720              79726               79726          INCIDENTE GRAVE
# 5721              79729               79729                 ACIDENTE
# 5722              79738               79738                INCIDENTE
# 5723              79737               79737                INCIDENTE
# 5724              79740               79740                INCIDENTE
# 5725              79741               79741                INCIDENTE
# 5726              79742               79742                 ACIDENTE
# 5727              79743               79743                 ACIDENTE
# 5728              79744               79744                INCIDENTE
# 5730              79785               79785                INCIDENTE
#
#           ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 5719   SÃO JOSÉ DOS PINHAIS            PR                 SSUL     2020-12-13
# 5720         BELO HORIZONTE            MG                 SBPR     2020-12-13
# 5721              TAILÂNDIA            PA                  NaN     2020-12-15
# 5722              ITUMBIARA            GO                  NaN     2020-12-16
# 5723         BELO HORIZONTE            MG                 SBBH     2020-12-17
# 5724              RIO LARGO            AL                 SBMO     2020-12-17
# 5725         BELO HORIZONTE            MG                 SBBH     2020-12-18
# 5726  SANTA HELENA DE GOIÁS            GO                  NaN     2020-12-18
# 5727               GOIATUBA            GO                  NaN     2020-12-18
# 5728         BELO HORIZONTE            MG                 SBCF     2020-12-18
# 5730                 MANAUS            AM                 SBEG     2020-12-19
#
#      ocorrencia_hora  total_recomendacoes ocorrencia_dia_hora
# 5719        16:15:00                    0 2020-12-13 16:15:00
# 5720        13:41:00                    0 2020-12-13 13:41:00
# 5721        20:00:00                    0 2020-12-15 20:00:00
# 5722        20:30:00                    0 2020-12-16 20:30:00
# 5723        17:13:00                    0 2020-12-17 17:13:00
# 5724        14:26:00                    0 2020-12-17 14:26:00
# 5725        22:57:00                    0 2020-12-18 22:57:00
# 5726        14:00:00                    0 2020-12-18 14:00:00
# 5727        13:00:00                    0 2020-12-18 13:00:00
# 5728        02:34:00                    0 2020-12-18 02:34:00
# 5730        12:37:00                    0 2020-12-19 12:37:00
